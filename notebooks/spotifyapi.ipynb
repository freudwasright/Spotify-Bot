# %%
import torch
import numpy as np
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
# f=2*x
x = torch.tensor([[1], [2], [3], [4]], dtype=torch.float)
y = torch.tensor([[2], [4], [6], [8]], dtype=torch.float)
w = torch.tensor([0.0], requires_grad=True)

# %%
w.dtype
class RegressionModel(torch.nn.Module):
    def __init__(self, input_dim, output_dim):
        super(RegressionModel, self).__init__()
        self.Dense = torch.nn.Linear(input_dim, output_dim)
        
    def forward(self, x):
        return self.Dense(x)

# %%
model = RegressionModel(1, 1)

# %%
# dataset
data

# %%
model.parameters

# %%
# model prediction
def forward_pass(x, w):
    return w * x

# %%
# loss
def mean_quadratic_loss(y_pred, y):
    return torch.pow((y_pred - y), 2).mean()

# %%
def backward_pass(y_pred, x, y):
    return (2 * x * (y_pred - y)).mean()

# %%
for data, target in zip(x, y):
    print(data)

# %%
lr = 1e-2
loss = torch.nn.MSELoss()
# optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

# %%
for i in range(60):
    for data, target in zip(x, y):    
        y_pred = model(data)
        cost = loss(y_pred, target)
        cost.backward()

        # update
        optimizer.step()
        optimizer.zero_grad()

        print(f"the cost of the current iteration is: {cost}")
# Out:
# the cost of the current iteration is: 0.0495019368827343
# the cost of the current iteration is: 0.011842095293104649
# the cost of the current iteration is: 0.000125044010928832
# the cost of the current iteration is: 0.01378201600164175
# the cost of the current iteration is: 0.04826614260673523
# the cost of the current iteration is: 0.011546528898179531
# the cost of the current iteration is: 0.00012192837311886251
# the cost of the current iteration is: 0.013437904417514801
# the cost of the current iteration is: 0.04706127569079399
# the cost of the current iteration is: 0.011258238926529884
# the cost of the current iteration is: 0.0001188936221296899
# the cost of the current iteration is: 0.013102509081363678
# the cost of the current iteration is: 0.04588644951581955
# the cost of the current iteration is: 0.010977190919220448
# the cost of the current iteration is: 0.00011591765360208228
# the cost of the current iteration is: 0.01277555525302887
# ...

# %%
for i in range(20):
    y_pred = forward_pass(x, w)
    cost = mean_quadratic_loss(y_pred, y)
    cost.backward()
    #gradient_w = backward_pass(y_pred, x, y)
    
    # update
    with torch.no_grad():
        w -= lr * w.grad
    w.grad.zero_()
    print(f"the cost of the current iteration is: {cost}")
    print(w.grad)

# %%
model(x[1])
# Out:
# tensor([4.0572], grad_fn=<AddBackward0>)
